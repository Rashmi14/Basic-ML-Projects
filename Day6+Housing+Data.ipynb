# %%
import numpy as np

# %%
import pandas as pd

# %%
mydata=pd.read_csv(r"C:\Users\Dr P.c rawat\Desktop\DataSets-master\Housing_Data.csv")

# %%
mydata.head()#by default it takes value 5, constructor
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
x_data=mydata["lotsize"]

# %%
x_data
# Out:
# 0       5850
# 1       4000
# 2       3060
# 3       6650
# 4       6360
# 5       4160
# 6       3880
# 7       4160
# 8       4800
# 9       5500
# 10      7200
# 11      3000
# 12      1700
# 13      2880
# 14      3600
# 15      3185
# 16      3300
# 17      5200
# 18      3450
# 19      3986
# 20      4785
# 21      4510
# 22      4000
# 23      3934
# 24      4960
# 25      3000
# 26      3800
# 27      4960
# 28      3000
# 29      4500
#        ...
# 516     6000
# 517     6000
# 518     6240
# 519     6000
# 520     7680
# 521     6000
# 522     6000
# 523     6000
# 524     6000
# 525     7475
# 526     5150
# 527     6325
# 528     6000
# 529     6000
# 530     6000
# 531     7000
# 532    12900
# 533     7686
# 534     5000
# 535     5800
# 536     6000
# 537     4800
# 538     6500
# 539     7320
# 540     6525
# 541     4800
# 542     6000
# 543     6000
# 544     6000
# 545     6000
# Name: lotsize, dtype: int64

# %%
y_data=mydata["price"]

# %%
y_data
# Out:
# 0       42000.0
# 1       38500.0
# 2       49500.0
# 3       60500.0
# 4       61000.0
# 5       66000.0
# 6       66000.0
# 7       69000.0
# 8       83800.0
# 9       88500.0
# 10      90000.0
# 11      30500.0
# 12      27000.0
# 13      36000.0
# 14      37000.0
# 15      37900.0
# 16      40500.0
# 17      40750.0
# 18      45000.0
# 19      45000.0
# 20      48500.0
# 21      65900.0
# 22      37900.0
# 23      38000.0
# 24      42000.0
# 25      42300.0
# 26      43500.0
# 27      44000.0
# 28      44500.0
# 29      44900.0
#          ...
# 516     95000.0
# 517     96500.0
# 518    101000.0
# 519    102000.0
# 520    103000.0
# 521    105000.0
# 522    108000.0
# 523    110000.0
# 524    113000.0
# 525    120000.0
# 526    105000.0
# 527    106000.0
# 528    107500.0
# 529    108000.0
# 530    113750.0
# 531    120000.0
# 532     70000.0
# 533     71000.0
# 534     82000.0
# 535     82000.0
# 536     82500.0
# 537     83000.0
# 538     84000.0
# 539     85000.0
# ...

# %%
y_data.shape
# Out:
# (546,)

# %%
y_data.shape
# Out:
# (546,)

# %%
x_data.shape
# Out:
# (546,)

# %%
x_cr=x_data.reshape(len(x_data),1)
# Out:
# C:\Users\Dr P.c rawat\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   if __name__ == '__main__':

# %%
x_cr
# Out:
# array([[ 5850],
#        [ 4000],
#        [ 3060],
#        [ 6650],
#        [ 6360],
#        [ 4160],
#        [ 3880],
#        [ 4160],
#        [ 4800],
#        [ 5500],
#        [ 7200],
#        [ 3000],
#        [ 1700],
#        [ 2880],
#        [ 3600],
#        [ 3185],
#        [ 3300],
#        [ 5200],
#        [ 3450],
#        [ 3986],
#        [ 4785],
#        [ 4510],
#        [ 4000],
#        [ 3934],
#        [ 4960],
#        [ 3000],
#        [ 3800],
#        [ 4960],
#        [ 3000],
#        [ 4500],
#        [ 3500],
#        [ 3500],
#        [ 4000],
#        [ 4500],
#        [ 6360],
#        [ 4500],
#        [ 4032],
#        [ 5170],
#        [ 5400],
#        [ 3150],
#        [ 3745],
#        [ 4520],
#        [ 4640],
#        [ 8580],
#        [ 2000],
#        [ 2160],
#        [ 3040],
#        [ 3090],
#        [ 4960],
#        [ 3350],
#        [ 5300],
#        [ 4100],
#        [ 9166],
#        [ 4040],
#        [ 3630],
# ...

# %%
y_cr=y_data.reshape(len(y_data),1)
# Out:
# C:\Users\Dr P.c rawat\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   if __name__ == '__main__':

# %%
y_cr
# Out:
# array([[  42000.],
#        [  38500.],
#        [  49500.],
#        [  60500.],
#        [  61000.],
#        [  66000.],
#        [  66000.],
#        [  69000.],
#        [  83800.],
#        [  88500.],
#        [  90000.],
#        [  30500.],
#        [  27000.],
#        [  36000.],
#        [  37000.],
#        [  37900.],
#        [  40500.],
#        [  40750.],
#        [  45000.],
#        [  45000.],
#        [  48500.],
#        [  65900.],
#        [  37900.],
#        [  38000.],
#        [  42000.],
#        [  42300.],
#        [  43500.],
#        [  44000.],
#        [  44500.],
#        [  44900.],
#        [  45000.],
#        [  48000.],
#        [  49000.],
#        [  51500.],
#        [  61000.],
#        [  61000.],
#        [  61700.],
#        [  67000.],
#        [  82000.],
#        [  54500.],
#        [  66500.],
#        [  70000.],
#        [  82000.],
#        [  92000.],
#        [  38000.],
#        [  44000.],
#        [  41000.],
# ...

# %%
y_cr.ndim
# Out:
# 2

# %%
x_ntrain=x_cr[:-250]

# %%
x_ntrain.shape
# Out:
# (296, 1)

# %%
x_ntest=x_cr[-250:]

# %%
x_ntest.shape
# Out:
# (250, 1)

# %%
y_ntrain=y_cr[:-250]

# %%
y_ntest=y_cr[-250:]

# %%
y_ntrain.shape
# Out:
# (296, 1)

# %%
y_ntest.shape
# Out:
# (250, 1)

# %%
y_ntest
# Out:
# array([[  50000.],
#        [  50000.],
#        [  52900.],
#        [  53000.],
#        [  55000.],
#        [  56000.],
#        [  58500.],
#        [  59500.],
#        [  60000.],
#        [  64000.],
#        [  67000.],
#        [  68100.],
#        [  70000.],
#        [  72000.],
#        [  57500.],
#        [  69900.],
#        [  70000.],
#        [  75000.],
#        [  76900.],
#        [  78000.],
#        [  80000.],
#        [  82000.],
#        [  83000.],
#        [  83000.],
#        [  83900.],
#        [  88500.],
#        [  93000.],
#        [  98000.],
#        [  98500.],
#        [  99000.],
#        [ 101000.],
#        [ 110000.],
#        [ 115442.],
#        [ 120000.],
#        [ 124000.],
#        [ 175000.],
#        [  50000.],
#        [  55000.],
#        [  60000.],
#        [  61000.],
#        [ 106000.],
#        [ 155000.],
#        [ 141000.],
#        [  62500.],
#        [  70000.],
#        [  73000.],
#        [  80000.],
# ...

# %%
from sklearn.linear_model import LinearRegression#all the algorithms are defined in sklearn

# %%
myler=LinearRegression()

# %%
mymodel=myler.fit(x_ntrain,y_ntrain)

# %%
yp=mymodel.predict(x_ntest)

# %%
yp
# Out:
# array([[  67141.19088269],
#        [  50094.61514038],
#        [  64381.85308268],
#        [  55735.92797597],
#        [  55981.20244708],
#        [  80508.64955832],
#        [  55735.92797597],
#        [  55981.20244708],
#        [  66528.00470491],
#        [  67049.21295603],
#        [  90239.91419971],
#        [  51934.17367372],
#        [  66528.00470491],
#        [  77565.35590497],
#        [  64075.25999379],
#        [  61591.85597378],
#        [  49358.79172704],
#        [  64688.44617157],
#        [  70513.71486049],
#        [  69042.06803382],
#        [  61622.51528266],
#        [  61622.51528266],
#        [  66699.69683469],
#        [  62848.88763823],
#        [  64688.44617157],
#        [  69900.52868271],
#        [  81551.06606055],
#        [  67754.37706048],
#        [  78178.54208275],
#        [  85414.13898057],
#        [  85414.13898057],
#        [  70697.67071382],
#        [  73886.23883829],
#        [  85383.47967168],
# ...

# %%
ya=y_ntest

# %%
mydata=pd.DataFrame([["actual value",ya],["predicted value",yp]])

# %%
mydata
# Out:
#                  0                                                  1
# 0     actual value  [[50000.0], [50000.0], [52900.0], [53000.0], [...
# 1  predicted value  [[67141.1908827], [50094.6151404], [64381.8530...

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x_ntest,y_ntest,'*r')
plt.plot(x_ntest,yp,'g')
plt.xlabel("Lotsize")
plt.ylabel("price")
plt.show()

# %%
ys=mymodel.predict(6000)

# %%
ys
# Out:
# array([[ 67754.37706048]])

# %%
mymodel.intercept_
# Out:
# array([ 30963.20639361])

# %%
mymodel.coef_
# Out:
# array([[ 6.13186178]])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_ntest,yp)
# Out:
# 19657.844966318258

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_ntest,ya)
# Out:
# 0.0
